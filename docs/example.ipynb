# %% [markdown]
# # Example usage
#
# To use `intakeinformer` in a project:

# %%
pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple/ intakeinformer==0.1.6 --upgrade
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple/
# Collecting intakeinformer==0.1.6
#   Obtaining dependency information for intakeinformer==0.1.6 from https://test-files.pythonhosted.org/packages/3d/d9/95c0ae5314462b68dcbdeaf627ff24fcdbc280bed3b2f884eec1f46c979c/intakeinformer-0.1.6-py3-none-any.whl.metadata
#   Downloading https://test-files.pythonhosted.org/packages/3d/d9/95c0ae5314462b68dcbdeaf627ff24fcdbc280bed3b2f884eec1f46c979c/intakeinformer-0.1.6-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.3 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from intakeinformer==0.1.6) (4.12.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.8.2 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from intakeinformer==0.1.6) (3.8.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.2 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from intakeinformer==0.1.6) (1.26.2)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from intakeinformer==0.1.6) (2.1.4)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from intakeinformer==0.1.6) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.9.3->intakeinformer==0.1.6) (2.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.2->intakeinformer==0.1.6) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.2->intakeinformer==0.1.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.2->intakeinformer==0.1.6) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.2->intakeinformer==0.1.6) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.2->intakeinformer==0.1.6) (23.1)
# Requirement already satisfied: pillow>=8 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.2->intakeinformer==0.1.6) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.2->intakeinformer==0.1.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.8.2->intakeinformer==0.1.6) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->intakeinformer==0.1.6) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from pandas<3.0.0,>=2.1.4->intakeinformer==0.1.6) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->intakeinformer==0.1.6) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->intakeinformer==0.1.6) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->intakeinformer==0.1.6) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from requests<3.0.0,>=2.31.0->intakeinformer==0.1.6) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /Users/starsrain/Library/Caches/pypoetry/virtualenvs/xiong-junchen-qItSjsd1-py3.10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.8.2->intakeinformer==0.1.6) (1.16.0)
# Downloading https://test-files.pythonhosted.org/packages/3d/d9/95c0ae5314462b68dcbdeaf627ff24fcdbc280bed3b2f884eec1f46c979c/intakeinformer-0.1.6-py3-none-any.whl (14 kB)
# Installing collected packages: intakeinformer
#   Attempting uninstall: intakeinformer
#     Found existing installation: intakeinformer 0.1.5
#     Uninstalling intakeinformer-0.1.5:
#       Successfully uninstalled intakeinformer-0.1.5
# Successfully installed intakeinformer-0.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from intakeinformer import get_calories_for_food_query, dri_benchmark
import os

# %%
# Please follow the steps outlined in the "Getting Started with IntakeInformer" section to obtain a valid USDA API KEY.
# The example here is based on the API Key of the developer.
os.environ['POETRY_FDC_API_KEY'] = 'KjfFHgeGLL6dkDEd5esxF0YyAQSNNEMzNGVuocf5'

# %%
my_api_key = os.getenv('POETRY_FDC_API_KEY')

# %%
# Test get_calories_for_food_query function
calorie_info = get_calories_for_food_query(my_api_key, "apple", "banana")
print(calorie_info)
# Out:
# Select an item for 'apple':
# 1: APPLE CHIPS (Bare Foods Co., 30.0g)
# 2: APPLE CRUMBLE (CHUDLEIGH'S, 114.0g)
# 3: APPLE DANISH (NOT A BRANDED ITEM, 92.0g)
# 4: APPLE PIE (LOVE SWEETS, 123.0g)
# 5: APPLE PIE (ROCK MOUNT PIES, 122.0g)
# 6: APPLE PIE (FRESH, 123.0g)
# 7: APPLE PIE (LOVE FOOD, 123.0g)
# 8: APPLES SLICES (RICHLAND HILLS FARMS, 57.0g)
# 9: EASTERN APPLES (Produce Marketing Association, 154.0g)
# 10: GALA APPLES (DISNEY PIXAR, 182.0g)
# Enter the number of your choice:  9
# Select an item for 'banana':
# 1: BANANA FREEZE DRIED FRUIT (LA FRUTA DICE, 20.0g)
# 2: BANANA WALNUT LOAF CAKE (PUBLIX BAKERY, 57.0g)
# 3: BRUNCH BANANA WALNUT BREAD (THE ORIGINAL YAHOO! BAKING CO, 53.0g)
# 4: CRUNCHY MUESLI WITH BANANA & CHOCOLATE (VITALIA NIKOLA LTD. THE HEALTH FOOD COMPANY, 55.0g)
# 5: STONYFIELD, SMOOTHIE, STRAWBERRY BANANA (Stonyfield Farm Inc, 177.0g)
# 6: DRIED FRUITS BANANA & PINEAPPLE BITS (EARTH UNIVERSITY, 40.0g)
# 7: TRADER JOE'S, DRIED FLATTENED BANANA (TRADER JOE'S, 40.0g)
# 8: SPARTAN, BANANA PEPPER RINGS, MILD (SPARTAN, 28.0g)
# 9: SPARTAN, BANANA PEPPER RINGS, HOT (SPARTAN, 28.0g)
# 10: METRO CANDY SALES, BANANA KISSES (METRO CANDY SALES, 43.0g)
# Enter the number of your choice:  2
# {'EASTERN APPLES': 33.77, 'BANANA WALNUT LOAF CAKE': 554.39, 'total': 588.15}

# %%
dri_benchmark(my_api_key, "apple", "cheedar cheese")
# Out:
# 1: APPLE CHIPS (Bare Foods Co., 30.0g)
# 2: APPLE CRUMBLE (CHUDLEIGH'S, 114.0g)
# 3: APPLE DANISH (NOT A BRANDED ITEM, 92.0g)
# 4: APPLE PIE (LOVE SWEETS, 123.0g)
# 5: APPLE PIE (ROCK MOUNT PIES, 122.0g)
# 6: APPLE PIE (FRESH, 123.0g)
# 7: APPLE PIE (LOVE FOOD, 123.0g)
# 8: APPLES SLICES (RICHLAND HILLS FARMS, 57.0g)
# 9: EASTERN APPLES (Produce Marketing Association, 154.0g)
# 10: GALA APPLES (DISNEY PIXAR, 182.0g)
# Enter the number of your choice:  9
# 1: MCCALL'S SHAMROCK CHEESE, IRISH CHEDDAR CHEESE (MCCALL'S SHAMROCK CHEESE, 28.0g)
# 2: CRUMBLED CHEESE (Alouette Cheese USA LLC, 28.0g)
# 3: MAC & CHEESE (B&G Foods North America, Inc., 71.0g)
# 4: CHEESE PIZZA (FRESH FOOD MARKET, 129.0g)
# 5: ASADERO CHEESE (COCINA SELECTA, 28.0g)
# 6: ASIAGO CHEESE (BELGIOIOSO, 28.0g)
# 7: BLUE CHEESE (ROGUE CREAMERY, 28.0g)
# 8: CHEDDAR CHEESE (BLACK DIAMOND, 28.0g)
# 9: CHUNK OF CHEESE (QUESO DESMORONADO, 28.0g)
# 10: COLBY CHEESE (CADY CREEK FARMS, 28.0g)
# Enter the number of your choice:  8
# Please select your life stage category:
# 1. Infants
# 2. Children
# 3. Males
# 4. Females
# 5. Pregnancy
# 6. Lactation
# Enter the number of your choice:  3
# Please select your age range for the 'Males' category:
# 1. 9–13 y
# 2. 14–18 y
# 3. 19–30 y
# 4. 31–50 y
# 5. 51–70 y
# 6. > 70 y
# Enter the number of your choice:  3
